# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-coder-alt/Level_1_Task_1/blob/main/Level_1_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📌 Step 1: Import Required Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 📌 Step 2: Load the Dataset
# Replace with your actual file path
file_path = 'Dataset .csv'
df = pd.read_csv(file_path)

# %%
# 📌 Step 3: Drop rows with missing 'Cuisines'
df_clean = df.dropna(subset=['Cuisines'])

# %%
# 📌 Step 4: Split and count cuisines
cuisine_counts = df_clean['Cuisines'].str.split(', ').explode().value_counts()

# %%
# 📌 Step 5: Get top 3 most common cuisines
top_3_cuisines = cuisine_counts.head(3)

# %%
# 📌 Step 6: Calculate total restaurants and percentages
total_restaurants = len(df_clean)
top_3_percentages = (top_3_cuisines / total_restaurants * 100).round(2)

# %%
# 📌 Step 7: Create a summary DataFrame
summary_df = pd.DataFrame({
    'Cuisine': top_3_cuisines.index,
    'Count': top_3_cuisines.values,
    'Percentage': top_3_percentages.values
})

# %%
# Display the summary
print("Top 3 Most Common Cuisines:")
display(summary_df)
# Out:
# Top 3 Most Common Cuisines:
#         Cuisine  Count  Percentage
# 0  North Indian   3960       41.50
# 1       Chinese   2735       28.66
# 2     Fast Food   1986       20.81

# %%
# 📊 Step 8: Visualization - Bar Chart
plt.figure(figsize=(8, 5))
bars = plt.bar(summary_df['Cuisine'], summary_df['Percentage'], color='skyblue')
plt.title('Top 3 Most Common Cuisines (by Percentage)')
plt.xlabel('Cuisine')
plt.ylabel('Percentage of Restaurants')
plt.ylim(0, max(summary_df['Percentage']) + 10)
# Out:
# (0.0, 51.5)

# %%
# Add percentage labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1, f'{height}%',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-12-8ea74fda8d84>:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
